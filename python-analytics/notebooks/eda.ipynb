# %% [markdown]
# # CleanFlow — exploratory data analysis
#
# Run from repo root with `jupyter lab` / `jupyter notebook`, kernel using `python-analytics` venv.
#
# 1. Fetch orders (or load a CSV from `python-analytics/data/`).
# 2. Explore distributions before running `build_snapshot.py`.

# %%
import os
import sys

# Allow importing sibling scripts when cwd is notebooks/
sys.path.insert(0, os.path.abspath(os.path.join("..")))

import pandas as pd
from fetch_orders import fetch_all_orders, load_orders_csv

# df = fetch_all_orders()
# df = load_orders_csv("../data/orders_YYYYMMDD_HHMMSS.csv")
df = fetch_all_orders()
df.head()

# %%
df["status"].value_counts() if "status" in df.columns else "no status column"
